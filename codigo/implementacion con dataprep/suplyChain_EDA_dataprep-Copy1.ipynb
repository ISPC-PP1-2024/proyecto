# %%
#dataprep

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
df = pd.read_csv('C:\\Users\\Usuario\\Desktop\\2024\\materias\\CDIA\\2semestre\\pp1-cdia23\\ejemplo suply chain\\DataCoSupplyChainDataset.csv\\para jupyter\\argentina_brasil_mexico.csv', encoding='latin1', sep=';')
create_report(df).show()
# Out:
# Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# NumExpr defaulting to 8 threads.
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from dataprep.datasets import load_dataset
#       2 from dataprep.eda import create_report
#       3 df = pd.read_csv('C:\\Users\\Usuario\\Desktop\\2024\\materias\\CDIA\\2semestre\\pp1-cdia23\\ejemplo suply chain\\DataCoSupplyChainDataset.csv\\para jupyter\\argentina_brasil_mexico.csv', encoding='latin1', sep=';')
#
# File ~\anaconda3\lib\site-packages\dataprep\datasets\__init__.py:3
#       1 """This module implements load dataset related functions"""
# ...
